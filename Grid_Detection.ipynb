# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
chess = cv2.imread("C:/Users/romas/Downloads/2dchess.jpg")

# %%
type(chess)
# Out:
# numpy.ndarray

# %%
plt.imshow(chess)

# %%
graychess = cv2.cvtColor(chess,cv2.COLOR_BGR2GRAY)

# %%
result,corners = cv2.findChessboardCorners(chess,(7,7))

# %%
result
# Out:
# True

# %%
corners
# Out:
# array([[[ 37.278625,  37.316025]],
#
#        [[ 74.720856,  37.53588 ]],
#
#        [[112.23947 ,  37.345005]],
#
#        [[149.54001 ,  37.46812 ]],
#
#        [[187.23488 ,  37.225536]],
#
#        [[224.39024 ,  37.349464]],
#
#        [[261.7882  ,  37.310223]],
#
#        [[ 36.789295,  74.78195 ]],
#
#        [[ 74.49565 ,  74.4821  ]],
#
#        [[112.17784 ,  74.66823 ]],
#
#        [[149.40112 ,  74.882164]],
#
#        [[187.32568 ,  74.54243 ]],
#
#        [[224.29219 ,  74.55055 ]],
#
#        [[262.31326 ,  74.441864]],
#
#        [[ 37.310944, 112.072395]],
#
#        [[ 74.61396 , 112.08382 ]],
#
#        [[111.62811 , 111.85618 ]],
#
#        [[149.53096 , 112.00244 ]],
#
#        [[186.62581 , 111.62012 ]],
#
#        [[224.38452 , 111.96514 ]],
#
#        [[261.5987  , 111.967125]],
#
#        [[ 37.004868, 149.6176  ]],
#
#        [[ 74.65607 , 149.49457 ]],
#
#        [[111.92203 , 149.52043 ]],
#
#        [[149.51797 , 149.47198 ]],
#
#        [[186.84465 , 149.42386 ]],
#
#        [[224.33379 , 149.3151  ]],
#
#        [[262.18567 , 149.3428  ]],
#
#        [[ 37.436165, 187.31769 ]],
#
#        [[ 74.570854, 187.0403  ]],
#
#        [[111.57157 , 186.593   ]],
#
#        [[149.52005 , 186.99068 ]],
#
#        [[186.98613 , 186.68504 ]],
#
#        [[224.4192  , 186.8862  ]],
#
#        [[261.5753  , 186.60626 ]],
#
#        [[ 37.34256 , 224.19519 ]],
#
#        [[ 74.533844, 224.33348 ]],
#
#        [[112.09245 , 224.2871  ]],
#
#        [[149.4498  , 224.28415 ]],
#
#        [[187.06238 , 224.48059 ]],
#
#        [[224.34447 , 224.37837 ]],
#
#        [[261.5927  , 224.45135 ]],
#
#        [[ 37.393707, 262.04272 ]],
#
#        [[ 74.59577 , 262.0118  ]],
#
#        [[112.25684 , 261.78156 ]],
#
#        [[149.53442 , 261.5768  ]],
#
#        [[187.09976 , 261.63077 ]],
#
#        [[224.37204 , 261.58133 ]],
#
#        [[261.55545 , 261.54272 ]]], dtype=float32)

# %%
cv2.drawChessboardCorners(chess,(7,7),corners,result)
# Out:
# array([[159, 162, 166, ..., 112, 110, 109],
#        [165, 168, 172, ..., 123, 121, 120],
#        [169, 172, 176, ..., 115, 113, 112],
#        ...,
#        [112, 127, 125, ..., 174, 180, 173],
#        [104, 121, 123, ..., 174, 183, 148],
#        [ 89, 109, 115, ..., 168, 180, 113]], dtype=uint8)

# %%
plt.imshow(chess)

# %%
#Other similar grid functions are:

# %%
# 1) Detecting circles in a image: cv2.findCirclesGrid() function and then draw it on the image using drawChessboardCorners() function
