# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import cv2

# %%
img = cv2.imread("C:/Users/romas/Downloads/margot.jpg")

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (300, 234, 3)

# %%
plt.imshow(img)

# %%
new_img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

# %%
plt.imshow(new_img)

# %%
img_gray = cv2.imread("C:/Users/romas/Downloads/margot.jpg",cv2.IMREAD_GRAYSCALE)

# %%
img_gray
# Out:
# array([[226, 223, 221, ..., 222, 222, 225],
#        [224, 221, 219, ..., 221, 220, 222],
#        [223, 220, 218, ..., 220, 218, 220],
#        ...,
#        [  9,   9,   8, ..., 166, 171, 171],
#        [ 14,  11,   8, ..., 166, 171, 171],
#        [ 19,  12,   7, ..., 166, 171, 171]], dtype=uint8)

# %%
plt.imshow(img_gray, cmap='gray')

# %%
img_gray.shape
# Out:
# (300, 234)

# %%
new_img = cv2.resize(new_img,(800,1000))

# %%
plt.imshow(new_img)

# %%
w_ratio = 1
h_ratio = 1

# %%
new_img = cv2.resize(new_img,(0,0),new_img,w_ratio,h_ratio)

# %%
plt.imshow(new_img)

# %%
new_img = cv2.flip(new_img,0)

# %%
plt.imshow(new_img)

# %%
new_img = cv2.flip(new_img,0)

# %%
plt.imshow(new_img)

# %%
cv2.imwrite("brandnew_img.jpg",new_img)
# Out:
# True

# %%
fig = plt.figure(figsize=(10,8))
ax = fig.add_subplot(111)
ax.imshow(img_gray)

# %%
cv2.imshow('Margot',new_img)
cv2.waitKey()

# %%
while True:
    cv2.imshow('Robbie',new_img)
    if cv2.waitKey(1) & 0xFF ==27:
        break
cv2.destroyAllWindows()
